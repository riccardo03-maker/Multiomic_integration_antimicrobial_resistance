# %% [markdown]
# ## Train model with gene expression only

# %%
# !git clone https://github.com/riccardo03-maker/Multiomic_integration_antimicrobial_resistance.git
# !cd Multiomic_integration_antimicrobial_resistance/
# Out:
# Cloning into 'Multiomic_integration_antimicrobial_resistance'...
# remote: Enumerating objects: 279, done.
# remote: Counting objects: 100% (243/243), done.
# remote: Compressing objects: 100% (173/173), done.
# remote: Total 279 (delta 105), reused 193 (delta 55), pack-reused 36 (from 2)
# Receiving objects: 100% (279/279), 74.62 MiB | 22.54 MiB/s, done.
# Resolving deltas: 100% (110/110), done.

# %%
from Multiomic_integration_antimicrobial_resistance/neural_networks.neural_networks import neural_network_single_feature_type
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_621/2695977506.py in <cell line: 0>()
# ----> 1 from neural_networks.neural_networks import neural_network_single_feature_type
#
# ModuleNotFoundError: No module named 'neural_networks'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
neural_network_single_feature_type()
# Out:
# Epoch: 1, loss: tensor(6.0311, grad_fn=<NllLossBackward0>)
# Epoch: 2, loss: tensor(0.6238, grad_fn=<NllLossBackward0>)
# Epoch: 3, loss: tensor(0.5985, grad_fn=<NllLossBackward0>)
# Epoch: 4, loss: tensor(0.6174, grad_fn=<NllLossBackward0>)
# Epoch: 5, loss: tensor(0.6282, grad_fn=<NllLossBackward0>)
# Epoch: 6, loss: tensor(0.6249, grad_fn=<NllLossBackward0>)
# Epoch: 7, loss: tensor(0.6131, grad_fn=<NllLossBackward0>)
# Epoch: 8, loss: tensor(0.6014, grad_fn=<NllLossBackward0>)
# Epoch: 9, loss: tensor(0.5940, grad_fn=<NllLossBackward0>)
# Epoch: 10, loss: tensor(0.5916, grad_fn=<NllLossBackward0>)
# Epoch: 11, loss: tensor(0.5912, grad_fn=<NllLossBackward0>)
# Epoch: 12, loss: tensor(0.5898, grad_fn=<NllLossBackward0>)
# Epoch: 13, loss: tensor(0.5856, grad_fn=<NllLossBackward0>)
# Epoch: 14, loss: tensor(0.5779, grad_fn=<NllLossBackward0>)
# Epoch: 15, loss: tensor(0.5677, grad_fn=<NllLossBackward0>)
# Epoch: 16, loss: tensor(0.5571, grad_fn=<NllLossBackward0>)
# ...
